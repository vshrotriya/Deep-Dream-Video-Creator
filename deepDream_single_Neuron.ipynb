# %%
# !wget -nc --no-check-certificate https://storage.googleapis.com/download.tensorflow.org/models/inception5h.zip && unzip -n inception5h.zip
# !wget -nc https://sample-videos.com/video123/mp4/720/big_buck_bunny_720p_1mb.mp4
 
from io import BytesIO
from IPython.display import clear_output, Image, display
import numpy as np
import PIL.Image
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from __future__ import print_function
import cv2 , os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
model_fn = 'tensorflow_inception_graph.pb'
 
# creating TensorFlow session and loading the model
graph = tf.Graph()
sess = tf.InteractiveSession(graph=graph)
with tf.gfile.FastGFile(model_fn, 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
t_input = tf.placeholder(np.float32, name='input') # define the input tensor
imagenet_mean = 117.0
t_preprocessed = tf.expand_dims(t_input-imagenet_mean, 0)
tf.import_graph_def(graph_def, {'input':t_preprocessed})
 
def T(layer):
    '''Helper for getting layer output tensor'''
    return graph.get_tensor_by_name("import/%s:0"%layer)
# Out:
# File ‘inception5h.zip’ already there; not retrieving.
#
# Archive:  inception5h.zip
# File ‘big_buck_bunny_720p_1mb.mp4’ already there; not retrieving.
# WARNING: Logging before flag parsing goes to stderr.
# W0723 06:01:11.490255 139986922674048 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# W0723 06:01:11.773168 139986922674048 deprecation.py:323] From <ipython-input-1-8a350f687ad9>:19: __init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.

# %%
video_path = "/content/big_buck_bunny_720p_1mb.mp4"
def video_to_frames(path=video_path):
    cam = cv2.VideoCapture(path)
    # frame
    currentframe = 0

    while(True):
        
    # reading from frame
        ret,frame = cam.read()

        if ret:
            # if video is still left continue creating images
            path = '/content/sample_data/frames/'
            if not os.path.exists(path):
              os.makedirs(path)
            name = path + str(currentframe) + '.jpg'
            print ('Creating...' + name)

            # writing the extracted images
            cv2.imwrite(name, frame)

            # increasing counter so that it will
            # #show how many frames are created
            currentframe += 1
        else:
            break
video_to_frames()
# Out:
# Creating.../content/sample_data/frames/0.jpg
# Creating.../content/sample_data/frames/1.jpg
# Creating.../content/sample_data/frames/2.jpg
# Creating.../content/sample_data/frames/3.jpg
# Creating.../content/sample_data/frames/4.jpg
# Creating.../content/sample_data/frames/5.jpg
# Creating.../content/sample_data/frames/6.jpg
# Creating.../content/sample_data/frames/7.jpg
# Creating.../content/sample_data/frames/8.jpg
# Creating.../content/sample_data/frames/9.jpg
# Creating.../content/sample_data/frames/10.jpg
# Creating.../content/sample_data/frames/11.jpg
# Creating.../content/sample_data/frames/12.jpg
# Creating.../content/sample_data/frames/13.jpg
# Creating.../content/sample_data/frames/14.jpg
# Creating.../content/sample_data/frames/15.jpg
# Creating.../content/sample_data/frames/16.jpg
# Creating.../content/sample_data/frames/17.jpg
# Creating.../content/sample_data/frames/18.jpg
# Creating.../content/sample_data/frames/19.jpg
# Creating.../content/sample_data/frames/20.jpg
# Creating.../content/sample_data/frames/21.jpg
# Creating.../content/sample_data/frames/22.jpg
# Creating.../content/sample_data/frames/23.jpg
# Creating.../content/sample_data/frames/24.jpg
# Creating.../content/sample_data/frames/25.jpg
# Creating.../content/sample_data/frames/26.jpg
# Creating.../content/sample_data/frames/27.jpg
# Creating.../content/sample_data/frames/28.jpg
# Creating.../content/sample_data/frames/29.jpg
# Creating.../content/sample_data/frames/30.jpg
# Creating.../content/sample_data/frames/31.jpg
# Creating.../content/sample_data/frames/32.jpg
# Creating.../content/sample_data/frames/33.jpg
# Creating.../content/sample_data/frames/34.jpg
# Creating.../content/sample_data/frames/35.jpg
# Creating.../content/sample_data/frames/36.jpg
# Creating.../content/sample_data/frames/37.jpg
# Creating.../content/sample_data/frames/38.jpg
# Creating.../content/sample_data/frames/39.jpg
# Creating.../content/sample_data/frames/40.jpg
# Creating.../content/sample_data/frames/41.jpg
# Creating.../content/sample_data/frames/42.jpg
# Creating.../content/sample_data/frames/43.jpg
# Creating.../content/sample_data/frames/44.jpg
# Creating.../content/sample_data/frames/45.jpg
# Creating.../content/sample_data/frames/46.jpg
# Creating.../content/sample_data/frames/47.jpg
# Creating.../content/sample_data/frames/48.jpg
# Creating.../content/sample_data/frames/49.jpg
# Creating.../content/sample_data/frames/50.jpg
# Creating.../content/sample_data/frames/51.jpg
# Creating.../content/sample_data/frames/52.jpg
# Creating.../content/sample_data/frames/53.jpg
# Creating.../content/sample_data/frames/54.jpg
# Creating.../content/sample_data/frames/55.jpg
# Creating.../content/sample_data/frames/56.jpg
# Creating.../content/sample_data/frames/57.jpg
# Creating.../content/sample_data/frames/58.jpg
# Creating.../content/sample_data/frames/59.jpg
# Creating.../content/sample_data/frames/60.jpg
# Creating.../content/sample_data/frames/61.jpg
# Creating.../content/sample_data/frames/62.jpg
# Creating.../content/sample_data/frames/63.jpg
# Creating.../content/sample_data/frames/64.jpg
# Creating.../content/sample_data/frames/65.jpg
# Creating.../content/sample_data/frames/66.jpg
# Creating.../content/sample_data/frames/67.jpg
# Creating.../content/sample_data/frames/68.jpg
# Creating.../content/sample_data/frames/69.jpg
# Creating.../content/sample_data/frames/70.jpg
# Creating.../content/sample_data/frames/71.jpg
# Creating.../content/sample_data/frames/72.jpg
# Creating.../content/sample_data/frames/73.jpg
# Creating.../content/sample_data/frames/74.jpg
# Creating.../content/sample_data/frames/75.jpg
# Creating.../content/sample_data/frames/76.jpg
# Creating.../content/sample_data/frames/77.jpg
# Creating.../content/sample_data/frames/78.jpg
# Creating.../content/sample_data/frames/79.jpg
# Creating.../content/sample_data/frames/80.jpg
# Creating.../content/sample_data/frames/81.jpg
# Creating.../content/sample_data/frames/82.jpg
# Creating.../content/sample_data/frames/83.jpg
# Creating.../content/sample_data/frames/84.jpg
# Creating.../content/sample_data/frames/85.jpg
# Creating.../content/sample_data/frames/86.jpg
# Creating.../content/sample_data/frames/87.jpg
# Creating.../content/sample_data/frames/88.jpg
# Creating.../content/sample_data/frames/89.jpg
# Creating.../content/sample_data/frames/90.jpg
# Creating.../content/sample_data/frames/91.jpg
# Creating.../content/sample_data/frames/92.jpg
# Creating.../content/sample_data/frames/93.jpg
# Creating.../content/sample_data/frames/94.jpg
# Creating.../content/sample_data/frames/95.jpg
# Creating.../content/sample_data/frames/96.jpg
# Creating.../content/sample_data/frames/97.jpg
# Creating.../content/sample_data/frames/98.jpg
# Creating.../content/sample_data/frames/99.jpg
# Creating.../content/sample_data/frames/100.jpg
# Creating.../content/sample_data/frames/101.jpg
# Creating.../content/sample_data/frames/102.jpg
# Creating.../content/sample_data/frames/103.jpg
# Creating.../content/sample_data/frames/104.jpg
# Creating.../content/sample_data/frames/105.jpg
# Creating.../content/sample_data/frames/106.jpg
# Creating.../content/sample_data/frames/107.jpg
# Creating.../content/sample_data/frames/108.jpg
# Creating.../content/sample_data/frames/109.jpg
# Creating.../content/sample_data/frames/110.jpg
# Creating.../content/sample_data/frames/111.jpg
# Creating.../content/sample_data/frames/112.jpg
# Creating.../content/sample_data/frames/113.jpg
# Creating.../content/sample_data/frames/114.jpg
# Creating.../content/sample_data/frames/115.jpg
# Creating.../content/sample_data/frames/116.jpg
# Creating.../content/sample_data/frames/117.jpg
# Creating.../content/sample_data/frames/118.jpg
# Creating.../content/sample_data/frames/119.jpg
# Creating.../content/sample_data/frames/120.jpg
# Creating.../content/sample_data/frames/121.jpg
# Creating.../content/sample_data/frames/122.jpg
# Creating.../content/sample_data/frames/123.jpg
# Creating.../content/sample_data/frames/124.jpg
# Creating.../content/sample_data/frames/125.jpg
# Creating.../content/sample_data/frames/126.jpg
# Creating.../content/sample_data/frames/127.jpg
# Creating.../content/sample_data/frames/128.jpg
# Creating.../content/sample_data/frames/129.jpg
# Creating.../content/sample_data/frames/130.jpg
# Creating.../content/sample_data/frames/131.jpg

# %%
def showarray(a, fmt='jpeg'):
    a = np.uint8(np.clip(a, 0, 255))
    f = BytesIO()
    PIL.Image.fromarray(a).save(f, fmt)
    return Image(data=f.getvalue())

# %%
# These parameters let us control the strenth of the deepdream.
octave_n = 4
octave_scale = 1.4
iter_n = 10
strength = 200

# Helper function that uses TensorFlow to resize an image
def resize(img, new_size):
    return sess.run(tf.image.resize_bilinear(img[np.newaxis,:], new_size))[0]

# Apply gradients to an image in a seires of tiles
def calc_grad_tiled(img, t_grad, tile_size=256):
    '''Random shifts are applied to the image to blur tile boundaries over
    multiple iterations.'''
    h, w = img.shape[:2]
    sx, sy = np.random.randint(tile_size, size=2)
    # We randomly roll the image in x and y to avoid seams between tiles.
    img_shift = np.roll(np.roll(img, sx, 1), sy, 0)
    grad = np.zeros_like(img)
    for y in range(0, max(h-tile_size//2, tile_size),tile_size):
        for x in range(0, max(w-tile_size//2, tile_size),tile_size):
            sub = img_shift[y:y+tile_size,x:x+tile_size]
            g = sess.run(t_grad, {t_input:sub})
            grad[y:y+tile_size,x:x+tile_size] = g
    imggrad = np.roll(np.roll(grad, -sx, 1), -sy, 0)
    # Add the image gradient to the image and return the result
    return img + imggrad*(strength * 0.01 / (np.abs(imggrad).mean()+1e-7))

# Applies deepdream at multiple scales
def render_deepdream(t_obj, input_img, show_steps = True):
    # Collapse the optimization objective to a single number (the loss)
    t_score = tf.reduce_mean(t_obj)
    # We need the gradient of the image with respect to the objective
    t_grad = tf.gradients(t_score, t_input)[0]

    # split the image into a number of octaves (laplacian pyramid)
    img = input_img
    octaves = []
    for i in range(octave_n-1):
        lo = resize(img, np.int32(np.float32(img.shape[:2])/octave_scale))
        octaves.append(img-resize(lo, img.shape[:2]))
        img = lo

    # generate details octave by octave
    for octave in range(octave_n):
        if octave>0:
            hi = octaves[-octave]
            img = resize(img, hi.shape[:2])+hi
        for i in range(iter_n):
            img = calc_grad_tiled(img, t_grad)
        if show_steps:
            clear_output()
            display(showarray(img))
    return img

# %% [markdown]
# DEEP DREAM

# %%
octave_n = 4 #@param {type:"slider", max: 10}
octave_scale = 1.4 #@param {type:"number"}
iter_n = 10 #@param {type:"slider", max: 50}
strength = 200 #@param {type:"slider", max: 1000}
layer = "mixed4c"  #@param ["mixed3a", "mixed3b", "mixed4a", "mixed4c", "mixed5a"]
feature_channel = 139 #@param {type:"slider", max: 512}
layer = "mixed4d_3x3_bottleneck_pre_relu"  #@param ["mixed4d_3x3_bottleneck_pre_relu", "mixed3a", "mixed3b", "mixed4a", "mixed4c", "mixed5a"]

def load_images_from_folder(folder="/content/sample_data/frames/"):
    images = []
    for filename in os.listdir(folder):
        path = os.path.join(folder,filename)
        contents = open(path).read() 
        img0 = sess.run(tf.image.decode_image(contents))
        if feature_channel >= T(layer).shape[3]:
          print("Feature channel exceeds size of layer ", layer, " feature space. ")
          print("Choose a smaller channel number.")
        else:
          tensor = render_deepdream(T(layer)[:,:,:,feature_channel], img0)
        #tensor = render_deepdream(tf.square(T(layer)), img0)
        imng = showarray(tensor)
        display(imng)
        print(type(imng))
        path = '/content/sample_data/output/'
        if not os.path.exists(path):
          os.makedirs(path)
        _ = path +str(filename)
        open(_,'w').write(imng.data)
load_images_from_folder()
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-7-4ac5e7969c8d> in <module>()
#      27         _ = path +str(filename)
#      28         open(_,'w').write(imng.data)
# ---> 29 load_images_from_folder()
#
# <ipython-input-7-4ac5e7969c8d> in load_images_from_folder(folder)
#      17           print("Choose a smaller channel number.")
#      18         else:
# ---> 19           tensor = render_deepdream(T(layer)[:,:,:,feature_channel], img0)
#      20         #tensor = render_deepdream(tf.square(T(layer)), img0)
#      21         imng = showarray(tensor)
#
# <ipython-input-6-f1a71aa6a5ef> in render_deepdream(t_obj, input_img, show_steps)
#      48             img = resize(img, hi.shape[:2])+hi
#      49         for i in range(iter_n):
# ---> 50             img = calc_grad_tiled(img, t_grad)
#      51         if show_steps:
#      52             clear_output()
#
# <ipython-input-6-f1a71aa6a5ef> in calc_grad_tiled(img, t_grad, tile_size)
#      21         for x in range(0, max(w-tile_size//2, tile_size),tile_size):
#      22             sub = img_shift[y:y+tile_size,x:x+tile_size]
# ---> 23             g = sess.run(t_grad, {t_input:sub})
#      24             grad[y:y+tile_size,x:x+tile_size] = g
#      25     imggrad = np.roll(np.roll(grad, -sx, 1), -sy, 0)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     958     try:
#     959       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 960                          run_metadata_ptr)
#     961       if run_metadata:
#     962         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1181     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1182       results = self._do_run(handle, final_targets, final_fetches,
# -> 1183                              feed_dict_tensor, options, run_metadata)
#    1184     else:
#    1185       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1359     if handle is None:
#    1360       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1361                            run_metadata)
#    1362     else:
#    1363       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/client/session.pyc in _do_call(self, fn, *args)
#    1365   def _do_call(self, fn, *args):
#    1366     try:
# -> 1367       return fn(*args)
#    1368     except errors.OpError as e:
#    1369       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/client/session.pyc in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1350       self._extend_graph()
#    1351       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1352                                       target_list, run_metadata)
#    1353
#    1354     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/client/session.pyc in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1443     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1444                                             fetch_list, target_list,
# -> 1445                                             run_metadata)
#    1446
#    1447   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
